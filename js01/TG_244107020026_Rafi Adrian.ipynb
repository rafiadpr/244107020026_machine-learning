# %% [markdown]
# # Pyprep : untuk preprocessing data EEG
# # Scipy : untuk matematika lanjut, aljabar linear, signal processing
# # wandb : untuk untuk pelacakan eksperimen, visualisasi metrik pelatihan model machine learning
# # Pyprep : untuk pengolahan, analisis, dan pembacaan sinyal Elektrokardiogram (EKG)

# %% [markdown]
# # AI digunakan untuk merubah wajah atau suara seseorang tanpa izin demi menyebarkan hoax, menipu korban untuk mentransfer uang, atau mencemarkan nama baik.
# # Referensi : Jurnal "Politika Progresif : Jurnal Hukum, Politik dan Humaniora"
#
# # Pelatihan LLM dan data centers memakai daya listrik besar yang masih bergantung pada bahan bakar fosil, sehingga meningkatkan emisi karbon global serta konsumsi air pendingin yang banyak.
